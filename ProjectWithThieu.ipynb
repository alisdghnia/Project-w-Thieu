# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_csv('sales_train.csv')

# %%
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
## Count of negative value for item cnt day --> possibly more returns than purchases
len(df[df['item_cnt_day'] < 0])
# Out:
# 7356

# %%
y = df['item_cnt_day']

# %%
y[y<0].unique()
# Out:
# array([ -1.,  -5.,  -6.,  -3.,  -2.,  -4., -22., -16.,  -9.])

# %%
len(df)
# Out:
# 2935849

# %%
df1 = df[df['item_cnt_day'] > 0]

# %%
df1.reset_index(drop = True)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        06.01.2013               0       25     2554     1709.05
# 3        15.01.2013               0       25     2555     1099.00
# 4        10.01.2013               0       25     2564      349.00
# ...             ...             ...      ...      ...         ...
# 2928488  10.10.2015              33       25     7409      299.00
# 2928489  09.10.2015              33       25     7460      299.00
# 2928490  14.10.2015              33       25     7459      349.00
# 2928491  22.10.2015              33       25     7440      299.00
# 2928492  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
len(df1)
# Out:
# 2928493

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df1['item_price'], df1.item_id)
plt.show()

# %%
df2 = df1[df1.item_price < 250000]

# %%
df2.reset_index(drop = True)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        06.01.2013               0       25     2554     1709.05
# 3        15.01.2013               0       25     2555     1099.00
# 4        10.01.2013               0       25     2564      349.00
# ...             ...             ...      ...      ...         ...
# 2928487  10.10.2015              33       25     7409      299.00
# 2928488  09.10.2015              33       25     7460      299.00
# 2928489  14.10.2015              33       25     7459      349.00
# 2928490  22.10.2015              33       25     7440      299.00
# 2928491  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
df2
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# 5        10.01.2013               0       25     2564      349.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 3                 1.0
# 4                 1.0
# 5                 1.0
# ...               ...
# ...

# %%
df1[df1.item_id == 6066]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1163158  13.12.2013              11       12     6066    307980.0
#
#          item_cnt_day
# 1163158           1.0

# %%
shop12 = df1[df1.shop_id == 12]

# %%
np.mean(shop12.item_price)
# Out:
# 1458.6816469711266

# %%
name_df = pd.read_csv('items_en.csv')

# %%
name_df
# Out:
#                                                item_name  item_id  \
# 0                           ! POWER IN glamor (PLAST.) D        0
# 1      ! ABBYY FineReader 12 Professional Edition Ful...        1
# 2                               *** In the glory (UNV) D        2
# 3                                 *** BLUE WAVE (Univ) D        3
# 4                                      *** BOX (GLASS) D        4
# ...                                                  ...      ...
# 22165             Nuclear titbit 2 [PC, Digital Version]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id
# 0                    40
# 1                    76
# 2                    40
# 3                    40
# 4                    40
# ...

# %%
all_new_df = pd.merge(df2, name_df, left_on = df2.item_id, right_on = name_df.item_id)

# %%
all_new_df
# Out:
#          key_0        date  date_block_num  shop_id  item_id_x  item_price  \
# 0        22154  02.01.2013               0       59      22154       999.0
# 1        22154  23.01.2013               0       24      22154       999.0
# 2        22154  20.01.2013               0       27      22154       999.0
# 3        22154  02.01.2013               0       25      22154       999.0
# 4        22154  03.01.2013               0       25      22154       999.0
# ...        ...         ...             ...      ...        ...         ...
# 2928487   8428  17.10.2015              33       25       8428       249.0
# 2928488   7903  01.10.2015              33       25       7903     12198.0
# 2928489   7610  29.10.2015              33       25       7610      2890.0
# 2928490   7635  22.10.2015              33       25       7635      2100.0
# 2928491   7640  01.10.2015              33       25       7640      4040.0
#
# ...

# %%
all_new_df = all_new_df.drop(columns = ['key_0'])

# %%
all_new_df = all_new_df.drop(columns = ['date', 'item_id_y', 'item_name'])

# %%
all_new_df
# Out:
#          date_block_num  shop_id  item_id_x  item_price  item_cnt_day  \
# 0                     0       59      22154       999.0           1.0
# 1                     0       24      22154       999.0           1.0
# 2                     0       27      22154       999.0           1.0
# 3                     0       25      22154       999.0           1.0
# 4                     0       25      22154       999.0           1.0
# ...                 ...      ...        ...         ...           ...
# 2928487              33       25       8428       249.0           1.0
# 2928488              33       25       7903     12198.0           1.0
# 2928489              33       25       7610      2890.0           1.0
# 2928490              33       25       7635      2100.0           1.0
# 2928491              33       25       7640      4040.0           1.0
#
#          item_category_id
# 0                      37
# 1                      37
# 2                      37
# ...

# %%
test_df = pd.read_csv('test.csv')

# %%
test_df = test_df.drop(columns = ['ID'])

# %%
test_df
# Out:
#         shop_id  item_id
# 0             5     5037
# 1             5     5320
# 2             5     5233
# 3             5     5232
# 4             5     5268
# ...         ...      ...
# 214195       45    18454
# 214196       45    16188
# 214197       45    15757
# 214198       45    19648
# 214199       45      969
#
# [214200 rows x 2 columns]

# %%
X = all_new_df[['date_block_num', 'shop_id', 'item_id_x']]

# %%
y = all_new_df[['item_price']]

# %%
X
# Out:
#          date_block_num  shop_id  item_id_x
# 0                     0       59      22154
# 1                     0       24      22154
# 2                     0       27      22154
# 3                     0       25      22154
# 4                     0       25      22154
# ...                 ...      ...        ...
# 2928487              33       25       8428
# 2928488              33       25       7903
# 2928489              33       25       7610
# 2928490              33       25       7635
# 2928491              33       25       7640
#
# [2928492 rows x 3 columns]

# %%
test_df
# Out:
#         shop_id  item_id
# 0             5     5037
# 1             5     5320
# 2             5     5233
# 3             5     5232
# 4             5     5268
# ...         ...      ...
# 214195       45    18454
# 214196       45    16188
# 214197       45    15757
# 214198       45    19648
# 214199       45      969
#
# [214200 rows x 2 columns]

# %%
y
# Out:
#          item_price
# 0             999.0
# 1             999.0
# 2             999.0
# 3             999.0
# 4             999.0
# ...             ...
# 2928487       249.0
# 2928488     12198.0
# 2928489      2890.0
# 2928490      2100.0
# 2928491      4040.0
#
# [2928492 rows x 1 columns]

# %%
shop25 = all_new_df[all_new_df['shop_id'] == 25]

# %%
shop25
# Out:
#          date_block_num  shop_id  item_id_x  item_price  item_cnt_day  \
# 3                     0       25      22154       999.0           1.0
# 4                     0       25      22154       999.0           1.0
# 5                     0       25      22154       999.0           1.0
# 6                     0       25      22154       999.0           1.0
# 7                     0       25      22154       999.0           1.0
# ...                 ...      ...        ...         ...           ...
# 2928487              33       25       8428       249.0           1.0
# 2928488              33       25       7903     12198.0           1.0
# 2928489              33       25       7610      2890.0           1.0
# 2928490              33       25       7635      2100.0           1.0
# 2928491              33       25       7640      4040.0           1.0
#
#          item_category_id
# 3                      37
# 4                      37
# 5                      37
# ...

# %%
plt.scatter(shop25.item_id_x, shop25['item_price'])
plt.show()

# %%
itemrand = shop25[shop25.item_id_x == 22154]
itemrand
# Out:
#     date_block_num  shop_id  item_id_x  item_price  item_cnt_day  \
# 3                0       25      22154       999.0           1.0
# 4                0       25      22154       999.0           1.0
# 5                0       25      22154       999.0           1.0
# 6                0       25      22154       999.0           1.0
# 7                0       25      22154       999.0           1.0
# 49              31       25      22154       299.0           1.0
# 53              32       25      22154       299.0           1.0
#
#     item_category_id
# 3                 37
# 4                 37
# 5                 37
# 6                 37
# 7                 37
# 49                37
# 53                37

# %%
import seaborn as sns

# %%
sns.scatterplot(data = all_new_df['item_price'])
# Out:
# <AxesSubplot:ylabel='item_price'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
X_train, y_train = X, y

# %%
X_train.drop(columns='date_block_num', inplace=True)
# Out:
# C:\Users\minht\AppData\Local\Temp\ipykernel_14576\3123846901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns='date_block_num', inplace=True)

# %%
X_train = np.array([X_train['date_block_num'], X_train['shop_id'], X_train['item_id_x']]).T
y_train = np.array(y_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Data Scientists\Kaggle Project\ProjectWithThieu\ProjectWithThieu.ipynb Cell 43 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Scientists/Kaggle%20Project/ProjectWithThieu/ProjectWithThieu.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> X_train = np.array([X_train['date_block_num'], X_train['shop_id'], X_train['item_id_x']]).T
#       <a href='vscode-notebook-cell:/d%3A/Data%20Scientists/Kaggle%20Project/ProjectWithThieu/ProjectWithThieu.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> y_train = np.array(y_train)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X_test = test_df

# %%
X_test['date_block_num'] = 34
X_test
# Out:
#         shop_id  item_id  date_block_num
# 0             5     5037              34
# 1             5     5320              34
# 2             5     5233              34
# 3             5     5232              34
# 4             5     5268              34
# ...         ...      ...             ...
# 214195       45    18454              34
# 214196       45    16188              34
# 214197       45    15757              34
# 214198       45    19648              34
# 214199       45      969              34
#
# [214200 rows x 3 columns]

# %%
X_test
# Out:
#         shop_id  item_id
# 0             5     5037
# 1             5     5320
# 2             5     5233
# 3             5     5232
# 4             5     5268
# ...         ...      ...
# 214195       45    18454
# 214196       45    16188
# 214197       45    15757
# 214198       45    19648
# 214199       45      969
#
# [214200 rows x 2 columns]

# %%
all_new_df
# Out:
#          date_block_num  shop_id  item_id_x  item_price  item_cnt_day  \
# 0                     0       59      22154       999.0           1.0
# 1                     0       24      22154       999.0           1.0
# 2                     0       27      22154       999.0           1.0
# 3                     0       25      22154       999.0           1.0
# 4                     0       25      22154       999.0           1.0
# ...                 ...      ...        ...         ...           ...
# 2928487              33       25       8428       249.0           1.0
# 2928488              33       25       7903     12198.0           1.0
# 2928489              33       25       7610      2890.0           1.0
# 2928490              33       25       7635      2100.0           1.0
# 2928491              33       25       7640      4040.0           1.0
#
#          item_category_id
# 0                      37
# 1                      37
# 2                      37
# ...

# %%
y_test
# Out:
# array([[10397.83547187],
#        [10325.43125083],
#        [10347.68979228],
#        ...,
#        [ 7153.84866972],
#        [ 6158.35459169],
#        [10937.28902589]])

# %%
X_test.drop(columns=  'date_block_num', inplace=True)

# %%
X_test = X_test.values

# %%
X_train
# Out:
# array([[    0,    59, 22154],
#        [    0,    24, 22154],
#        [    0,    27, 22154],
#        ...,
#        [   33,    25,  7610],
#        [   33,    25,  7635],
#        [   33,    25,  7640]], dtype=int64)

# %%
y_train.reshape(-1,1)
# Out:
# array([[ 999.],
#        [ 999.],
#        [ 999.],
#        ...,
#        [2890.],
#        [2100.],
#        [4040.]])

# %%
from sklearn import preprocessing
from sklearn import utils

#convert y values to categorical values
lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(y_train)

#view transformed values
print(y_transformed)
# Out:
# c:\Users\minht\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [11105 11105 11105 ... 17214 15670 18159]

# %%
y_transformed = y_transformed.reshape(-1,1)
y_transformed.shape
# Out:
# (2928492, 1)

# %%
(X_train).shape
# Out:
# (2928492, 3)

# %%
from sklearn.linear_model import LogisticRegression

# train the model = fit logistic function to trainings data
model = LogisticRegression().fit(X_train, )

# Create predictions on the test set
print(y_test)
# Out:
# c:\Users\minht\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# d:\Data Scientists\Kaggle Project\ProjectWithThieu\ProjectWithThieu.ipynb Cell 52 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20Scientists/Kaggle%20Project/ProjectWithThieu/ProjectWithThieu.ipynb#Y100sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.linear_model import LogisticRegression
#       <a href='vscode-notebook-cell:/d%3A/Data%20Scientists/Kaggle%20Project/ProjectWithThieu/ProjectWithThieu.ipynb#Y100sZmlsZQ%3D%3D?line=2'>3</a> # train the model = fit logistic function to trainings data
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model = lr.fit(X_train, y_train)

# y_test = model.predict(X_test)  # create y-labels through the learned model

predict = model.predict(X_test)
print(predict)
# Out:
# [[1136.95619963]
#  [1126.64075654]
#  [1129.81193516]
#  ...
#  [ 661.37288524]
#  [ 519.54465533]
#  [1200.40034962]]
# c:\Users\minht\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - item_id
# Feature names seen at fit time, yet now missing:
# - item_id_x
#
#   warnings.warn(message, FutureWarning)

# %%
X_test
# Out:
# array([[   34,     5,  5037],
#        [   34,     5,  5320],
#        [   34,     5,  5233],
#        ...,
#        [   34,    45, 15757],
#        [   34,    45, 19648],
#        [   34,    45,   969]], dtype=int64)

# %%
model.coef_
# Out:
# array([[-2.1208947 , -0.03645033]])

# %%
from sklearn.metrics import r2_score

print(r2_score(predict, y_test))
# Out:
# -1138.289651661458

# %%
import seaborn as sns
sns.scatterplot(x=X_train, )
# Out:
# (214200, 1)

# %%
X_test = np.array([X_test['date_block_num'], X_test['shop_id'], X_test['item_id']])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Data Scientists\Kaggle Project\ProjectWithThieu\ProjectWithThieu.ipynb Cell 54 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Scientists/Kaggle%20Project/ProjectWithThieu/ProjectWithThieu.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> X_test = np.array([X_test['date_block_num'], X_test['shop_id'], X_test['item_id']])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X_test
# Out:
# array([[   34,     5,  5037],
#        [   34,     5,  5320],
#        [   34,     5,  5233],
#        ...,
#        [   34,    45, 15757],
#        [   34,    45, 19648],
#        [   34,    45,   969]], dtype=int64)

# %%
X_train.shape
# Out:
# (2928492, 3)

# %%
y_transformed.shape
# Out:
# (2928492,)

# %%
y_transformed
# Out:
# array([11105, 11105, 11105, ..., 17214, 15670, 18159], dtype=int64)
